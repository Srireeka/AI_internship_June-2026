# %%
for i in range (5):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=input()
b=input()
print(a+b)
a=(int(input()))
b=(int(input()))
print(a+b)
print(type(2))
# Out:
# 2
# 2
# 22
# 2
# 2
# 4
# <class 'int'>

# %%
fruits=["apple","banana","orange"]
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# orange

# %%
a=8
print(a>5 and a<10)
print(a>10 or a<10)
print(not(a<5))
# Out:
# True
# True
# True

# %%
age=19
if age >=18:
  print("eligible for voting")
# Out:
# eligible for voting

# %%
n="abinayakumar"
print(n.upper())
print(n.lower())
print(n.capitalize())
print(n.title())
print(n.swapcase())
# Out:
# ABINAYAKUMAR
# abinayakumar
# Abinayakumar
# Abinayakumar
# ABINAYAKUMAR

# %%
n="abinaya"
n[0:3]
n[-3:-1]
n[::2]
n[::-1]
# Out:
# 'ayaniba'

# %%
n="srireeka"
n[0:3]
n[-3:-1]
n[::2]
n[::-1]
# Out:
# 'akeerirs'

# %%
n="srireeka moorthi"
print(n.center(30))
print(n.ljust(30))
print(n.rjust(30))
print("".zfill(4))
# Out:
#        srireeka moorthi
# srireeka moorthi
#               srireeka moorthi
# 0000

# %%
n="srireeka moorthi"
print(n.strip())
print(n.strip())
print(n.strip())
# Out:
# srireeka moorthi
# srireeka moorthi
# srireeka moorthi

# %%
n="srireeka"
print(n.split())
m="srireeka"
print(m.split("K"))
p=""
print(p.join(["hi","hello"]))
s="srireeka"
print(s.rsplit("a"))
print("hi guys".partition(" "))
# Out:
# ['srireeka']
# ['srireeka']
# hihello
# ['srireek', '']
# ('hi', ' ', 'guys')

# %%
n="srireeka"
print(n.find("i"))
print(n.find("a"))
print(n.rfind("a"))
print(n.index('e'))
print(n.count("a"))
print(n.replace("a","$"))
print(n.startswith("a"))
print(n.endswith("r"))
# Out:
# 2
# 7
# 7
# 4
# 1
# srireek$
# False
# False
